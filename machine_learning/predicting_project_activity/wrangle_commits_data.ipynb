# %% [markdown]
# <h1>Produce commits by day</h1>
#
# Use rows in sorted_commits.csv to produce a count of commits for inclusive dates in the table. Each row represents a single commit.

# %%
project = 'spack'

# %%
import pandas as pd

# %%
sorted_commits = pd.read_csv('sorted_'+project+'_commits.csv')

# %%
len(sorted_commits)
# Out:
# 10913

# %%
sorted_commits.head(50)
# Out:
#      day_name  day_of_month  doy  \
# 0   Wednesday            13   44
# 1      Monday            18   49
# 2      Monday            18   49
# 3     Tuesday            19   50
# 4     Tuesday            19   50
# 5     Tuesday            19   50
# 6   Wednesday            20   51
# 7   Wednesday            20   51
# 8    Thursday            21   52
# 9    Thursday            21   52
# 10   Thursday            21   52
# 11   Thursday            21   52
# 12   Thursday            21   52
# 13   Thursday            21   52
# 14     Friday            22   53
# 15     Monday            25   56
# 16     Friday            22   81
# 17     Friday            22   81
# 18     Monday            25   84
# 19     Monday            25   84
# 20     Monday            25   84
# 21     Monday             8   98
# 22     Monday             8   98
# 23   Thursday             9  129
# 24   Thursday             9  129
# 25   Thursday             9  129
# 26   Thursday             9  129
# 27   Thursday             9  129
# 28     Sunday            12  132
# 29     Sunday            12  132
# 30     Sunday            12  132
# 31     Monday            13  133
# 32  Wednesday            15  135
# 33     Friday            17  137
# 34     Friday            17  137
# 35     Friday            17  137
# 36     Friday            17  137
# 37     Sunday             2  153
# 38   Saturday            29  180
# 39   Saturday            29  180
# 40   Saturday            29  180
# 41     Monday             7  280
# 42     Monday             7  280
# 43     Monday             7  280
# 44     Friday            11  284
# 45     Friday            11  284
# 46    Tuesday            15  288
# 47   Thursday            17  290
# 48   Thursday            17  290
# 49     Friday            18  291
#
#                                                 files  \
# 0                       [b'.gitignore', b'bin/spack']
# 1                                      [b'4 +1,4 @@']
# 2                       [b',7 +19,7 @@ import spack']
# 3   [b',7 +73,8 @@ for var in ["LD_LIBRARY_PATH", ...
# 4                          [b'28 +4,29 @@ import os']
# 5                [b',6 +10,7 @@ def get_path(name):']
# 6   [b',9 +65,9 @@ class MakeExecutable(Executable...
# 7                                    [b'12 +1,10 @@']
# 8          [b'5,6 +315,11 @@ class Package(object):']
# 9           [b'1,6 +131,9 @@ class Package(object):']
# 10  [b',6 +21,7 @@ parser = argparse.ArgumentParse...
# 11             [b'7 +3,7 @@ import spack.tty as tty']
# 12  [b',4 +38,4 @@ spack.verbose = args.verbose', ...
# 13  [b',9 +36,17 @@ curl = which("curl", required=...
# 14                     [b',9 +19,12 @@ import spack']
# 15                                     [b'3 +1,4 @@']
# 16            [b',7 +54,7 @@ class Package(object):']
# 17                                     [b'6 +1,5 @@']
# 18                                       [b'ev/null']
# 19             [b',8 +41,13 @@ prefix = os.getcwd()']
# 20                             [b'bin/install-spack']
# 21  [b",7 +29,8 @@ parser.add_argument('-d', '--de...
# 22                                                 []
# 23               [b'5 +2,6 @@ from globals import *']
# 24                                       [b'ev/null']
# 25  [b',4 +10,4 @@ def run(test_name, verbose=Fals...
# 26             [b'lib/spack/spack/test/url_parse.py']
# 27     [b' 50718fe57f225e45331deccd24eb53dbccbad685']
# 28  [b',6 +36,28 @@ line is a spec for a particula...
# 29                                     [b'7 +1,9 @@']
# 30                         [b'23 +2,33 @@ import re']
# 31                                     [b'7 +1,6 @@']
# 32                          [b'7 +5,8 @@ import sys']
# 33                                     [b'5 +1,6 @@']
# 34                                   [b'10 +1,19 @@']
# 35                   [b'lib/spack/spack/cmd/info.py']
# 36              [b',54 +27,59 @@ import spack.error']
# 37                                     [b'7 +1,9 @@']
# 38            [b',7 +61,7 @@ def parse_specs(args):']
# 39          [b'5,11 +155,17 @@ class Stage(object):']
# 40                      [b'lib/spack/spack/color.py']
# 41                           [b'9 +2,9 @@ import os']
# 42                                     [b'5 +1,5 @@']
# 43  [b',6 +19,7 @@ sys.path.insert(0, SPACK_LIB_PA...
# 44                 [b'lib/spack/spack/cmd/python.py']
# 45                    [b'lib/spack/spack/cmd/doc.py']
# 46  [b',6 +12,5 @@ def setup_parser(subparser):', ...
# 47    [b',22 +11,22 @@ def setup_parser(subparser):']
# 48    [b',14 +19,13 @@ def setup_parser(subparser):']
# 49          [b'0,7 +380,8 @@ class Package(object):']
#
#                                               message  month  \
# 0       Initial version of spack with one package:...      2
# 1                                 Require python2.7\n      2
# 2       Dependencies now work.  Added libelf, libd...      2
# 3       Fixed passing of dependence prefixes to cc...      2
# 4       Fixes, remove parallel build for libdwarf ...      2
# 5       rpaths for dependencies.  elf, dwarf, cmak...      2
# 6                Fixed bug in parallel make option.\n      2
# 7       Added libunwind and fixed link issues in c...      2
# 8       Better handling of stage.\n    - better sy...      2
# 9                     Parallel bootstrap for cmake.\n      2
# 10      Minor changes; loosened up parallel build ...      2
# 11                         Fix regression in clean.\n      2
# 12            Added help command and purge command.\n      2
# 13      Use tmp directory for downloading and buil...      2
# 14      Better spack -h: added cmd descriptions.\n...      2
# 15            Simpler implementation of depends_on.\n      2
# 16                                     Fix in docs.\n      3
# 17                 Documentation and small changes.\n      3
# 18      Moved install-spack to its own simpler com...      3
# 19      Print files that are in the way of install.\n      3
# 20                            Adding install script\n      3
# 21                          Better help formatting.\n      4
# 22      Merge pull request #1 from feature-platfor...      4
# 23      Initial implementation of package specs, i...      5
# 24                          Removed old versions.py\n      5
# 25                       Don't exit after one test.\n      5
# 26                              Changed class name.\n      5
# 27                          Removed executable bit.\n      5
# 28                              Added EBNF grammar.\n      5
# 29      Commands take specs as input instead of na...      5
# 30      More rubust spec parsing and error messages\n      5
# 31          list_modules will now find directories.\n      5
# 32      Use realpath in addition to expanduser to ...      5
# 33         Better error messages for spack list -v.\n      5
# 34      Ability to list versions from web page wit...      5
# 35      Added command to print out URL and homepag...      5
# 36        Renamed variables called 'spec' to 'path'\n      5
# 37                       Add checks for version 2.7\n      6
# 38      Add spec architeccture, redo color output ...      6
# 39               Clean up half-downloaded tarballs.\n      6
# 40      Adding expression syntax for console color...      6
# 41            Refactor utils into separate modules.\n     10
# 42      Start to make a bigger package out of util...     10
# 43      Checkpoint commit: much-improved spec clas...     10
# 44      Command to launch interpreter with spack i...     10
# 45           Command to run pydoc on spack classes.\n     10
# 46      Spec constraints and normalization now wor...     10
# 47      spack test runs all tests by default\n    ...     10
# 48      spec flatten, normalize, validate; package...     10
# 49         Added unit tests for spec normalization.\n     10
#
#                                    name  utc_offset  year
# 0   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 1   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 2   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 3   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 4   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 5   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 6   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 7   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 8   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 9   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 10  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 11  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 12  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 13  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 14  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 15  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 16  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 17  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 18  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 19  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 20  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 21  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 22  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 23  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 24  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 25  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 26  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 27  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 28  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 29  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 30  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 31  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 32  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 33  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 34  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 35  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 36  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 37  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 38  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 39  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 40  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 41  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 42  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 43  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 44  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 45  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 46  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 47  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 48  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 49  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013

# %%
import datetime
from dateutil import parser

# %% [markdown]
# ## Here is starting date

# %%
starting_year = sorted_commits.loc[0,'year']
starting_month = sorted_commits.loc[0,'month']
starting_day = sorted_commits.loc[0,'day_of_month']
starting_obj = datetime.date(starting_year, starting_month, starting_day)
starting_obj
# Out:
# datetime.date(2013, 2, 13)

# %% [markdown]
# ## Here is ending date

# %%
ending_year = sorted_commits.iloc[-1]['year']
ending_month = sorted_commits.iloc[-1]['month']
ending_day = sorted_commits.iloc[-1]['day_of_month']
ending_obj = datetime.date(ending_year, ending_month, ending_day)
ending_obj
# Out:
# datetime.date(2019, 7, 3)

# %% [markdown]
# We should end up with a list of this length, item for each day.

# %%
td = ending_obj - starting_obj
td.days
# Out:
# 2331

# %% [markdown]
# ## wrangling code
#
# Goal: go through everyday between starting and ending dates. For each day count how many commits occured, 0 is possible. Produce a list of commits per day.
#
# Actual method: loop through rows of table. Keep values needed to (a) count rows with same date, (b) count days skipped leading to a sequence of 0 entries, and (c) determine when switch years so can reset values.

# %%
current_day = int(sorted_commits.loc[0,'doy'])  #day of year: 1-365 (or 366 on leap years)
current_year = sorted_commits.loc[0,'year']

commits_by_day = []           #where final sequence will be kept
day_commits = 0               #count the commits for a single day
dnint = {'Monday':1, 'Tuesday':2, 'Wednesday':3, 'Thursday':4, 'Friday':5, 'Saturday':6, 'Sunday':7}

for i in range(len(sorted_commits)):

    #pull out data pieces
    year = int(sorted_commits.loc[i,'year'])
    day_of_year = int(sorted_commits.loc[i,'doy'])
    
    #check if change years, e.g., change from 2013 to 2014
    if year!=current_year:
        current_year = year
        diff = day_of_year + (365 - current_day)  #account for skipped days at end of old year
    else:
        diff = day_of_year - current_day
    
    #diff now holds number of days incremented
    
    #No diff so same day - increment commits for the day
    if diff==0:
        day_commits += 1
        continue
    
    #Now things are interesting. We need to move back in time to beginning edge of gap. If gap is size diff,
    #then move back diff days. That will give us the date before the gap begins.
    
    #First build date object - easier to do arithmetic on. This is date on ending edge of gap.
    month = int(sorted_commits.loc[i,'month'])
    day_of_month = int(sorted_commits.loc[i,'day_of_month'])
    end_gap_date = datetime.datetime(year, month, day_of_month)   #current row we are looking at
    
    begin_gap_date = end_gap_date - datetime.timedelta(days=diff) #looking back in time
    
    #First store commits that have been accumulating.
    prior_day_name = dnint[begin_gap_date.strftime('%A')]  #convert to int 1-7
    prior_month = begin_gap_date.month
    prior_day_of_month = begin_gap_date.day

    #record embedding for begin gap date
    embedding_data = [prior_day_name, prior_month, prior_day_of_month]
    the_embedding = embedding_data + [day_commits]
    commits_by_day.append(the_embedding)
    
    #Whew. Took care of recording data for the beginning data of gap. Now to fill in gap.
    
    #diff = 1 so tomorrow is here :) Just reset things since no dates skipped
    if diff == 1:
        day_commits = 1
        current_day = day_of_year
        continue
    
    #we have a gap! need to fill in with 0 embedding for each
    if diff > 1:
        date_obj = begin_gap_date
        for i in range(diff-1):
            date_obj += datetime.timedelta(days=1)  #handles month change overs
            day_name = dnint[date_obj.strftime('%A')]
            the_embedding = [day_name, date_obj.month, date_obj.day, 0]
            commits_by_day.append(the_embedding)  #fill in 0 for missing days 
        day_commits = 1  #record the new one we just saw for data at end of gap
        current_day = day_of_year  #now on new date
        continue
    
    print((i, day_of_year, year, diff))
    raise Exception  #should never get here

#check if have accumumlation before ending.
if day_commits:
    embedding_data = [prior_day_name, prior_month, prior_day_of_month]
    the_embedding = embedding_data + [day_commits]
    commits_by_day.append(the_embedding)

# %%
len(sorted_commits)
# Out:
# 10913

# %%
len(commits_by_day)
# Out:
# 2331

# %%
commits_by_day[:10]  #3=wednesday
# Out:
# [[3, 2, 13, 1],
#  [4, 2, 14, 0],
#  [5, 2, 15, 0],
#  [6, 2, 16, 0],
#  [7, 2, 17, 0],
#  [1, 2, 18, 2],
#  [2, 2, 19, 3],
#  [3, 2, 20, 2],
#  [4, 2, 21, 6],
#  [5, 2, 22, 1]]

# %%
just_commits = [rec[3] for rec in commits_by_day]

# %%
max(just_commits)  #49
# Out:
# 49

# %%
n = len(just_commits)
for i in range(max(just_commits)+1):
    print((i, just_commits.count(i)/n))

# %%
fee_fie_foo()  #break here from Run All to see if want to save

# %%
import json
with open('commit_'+project+'_counts.txt', 'w') as f:
    f.write(json.dumps(commits_by_day))

#Now read the file back into a Python list object
with open('commit_'+project+'_counts.txt', 'r') as f:
    a = json.loads(f.read())
    
len(a) == len(commits_by_day)
# Out:
# True

# %%
len(a)
# Out:
# 2331

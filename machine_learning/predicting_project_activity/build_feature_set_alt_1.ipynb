# %% [markdown]
# # What this notebook does
#
# It assumes that a separate notebook has built a csv table where each row is a day in the life of a project. The table is sorted by date. The goal of this notebook is to load that table and build a day-by-day feature set represented by a list. Each item in the list is a feature. A feature has at least these first 3 values: weekday as int, month as int, day_of_month as int. What further features are included is given by notebook extenstions such as alt_1, alt_2, etc.
#
# Once this notebook completes, and a build labels notebook completes, we are ready to train a model.

# %% [markdown]
# ## _alt_1
#
# Alternative 1 is to look at the following feature set. Reminder: these are values for a single day in the life of the project.
#
# * weekday
# * day_of_month
# * month
# * total_commits
# * total_locc  #lines of code changed across all commits
# * total_developers  #how many different developers were active on the day
# * total_files_changed

# %% [markdown]
# ## Assumptions of this notebook
#
# 1. The code and notebooks we will be using, including this one, are in the following folder: /ideas-uo/machine_learning/predicting_project_activity.
#
# 2. We expect to be able to execute this code: load_dir = repository_dir + '/machine_learning/predicting_project_activity/'; days_table = pd.read_csv(load_dir+project+'_days_table.csv').
#
# 3. Final result will be written to load_dir + project+'features_by_day_'.txt'.
#
# 4. This notebook should be started in folder /ideas-uo/machine_learning/predicting_project_activity.

# %% [markdown]
# ## Parameters for this notebook

# %%
project = 'spack'

# %% [markdown]
# ## Read the table based on commits
#
# Each row represents a separate commit.

# %%
import pandas as pd

# %%
days_table = pd.read_csv(project+'_days_table.csv')  #produced prior to this notebook

# %%
len(days_table)
# Out:
# 4972

# %%
days_table.head(50)
# Out:
#      day_name  day_of_month  doy  locc  \
# 0   Wednesday            13   44     4
# 1      Monday            18   49     2
# 2      Monday            18   49     2
# 3   Wednesday            20   51     1
# 4    Thursday            21   52     1
# 5      Friday            22   53     9
# 6      Monday            25   56     8
# 7      Monday            25   84    12
# 8      Monday            25   84    12
# 9    Thursday             9  129    11
# 10   Thursday             9  129    10
# 11     Sunday            12  132     1
# 12     Monday            13  133     7
# 13     Friday            17  137     1
# 14     Friday            17  137     2
# 15     Friday            17  137     5
# 16     Sunday             2  153     5
# 17   Saturday            29  180     6
# 18     Monday             7  280     2
# 19     Monday             7  280     1
# 20     Friday            11  284     7
# 21     Friday            11  284     3
# 22   Thursday            17  290     2
# 23   Saturday            23  327     4
# 24   Saturday            23  327     2
# 25     Sunday            24  328     3
# 26     Sunday             8  342     2
# 27     Monday             9  343     5
# 28     Monday             9  343     8
# 29   Thursday            12  346     2
# 30     Friday            20  354     1
# 31     Monday            23  357     2
# 32     Monday            23  357     2
# 33     Monday            23  357     3
# 34  Wednesday            25  359     1
# 35     Friday             3    3     1
# 36     Monday             6    6     2
# 37  Wednesday             8    8     2
# 38  Wednesday             8    8     4
# 39   Thursday             9    9     5
# 40   Thursday             9    9     7
# 41   Saturday            11   11     1
# 42     Sunday            12   12     2
# 43     Sunday            12   12    10
# 44     Monday            13   13     5
# 45     Monday            13   13    46
# 46    Tuesday            14   14     1
# 47  Wednesday            15   15    10
# 48     Sunday            26   26     2
# 49     Sunday            26   26     1
#
#                                               message  month  \
# 0       Initial version of spack with one package:...      2
# 1                                 Require python2.7\n      2
# 2       Dependencies now work.  Added libelf, libd...      2
# 3       Added libunwind and fixed link issues in c...      2
# 4       Minor changes; loosened up parallel build ...      2
# 5       Better spack -h: added cmd descriptions.\n...      2
# 6             Simpler implementation of depends_on.\n      2
# 7       Moved install-spack to its own simpler com...      3
# 8                             Adding install script\n      3
# 9                           Removed old versions.py\n      5
# 10                              Changed class name.\n      5
# 11      Commands take specs as input instead of na...      5
# 12          list_modules will now find directories.\n      5
# 13         Better error messages for spack list -v.\n      5
# 14      Ability to list versions from web page wit...      5
# 15      Added command to print out URL and homepag...      5
# 16                       Add checks for version 2.7\n      6
# 17      Adding expression syntax for console color...      6
# 18      Start to make a bigger package out of util...     10
# 19      Checkpoint commit: much-improved spec clas...     10
# 20      Command to launch interpreter with spack i...     10
# 21           Command to run pydoc on spack classes.\n     10
# 22      spack test runs all tests by default\n    ...     10
# 23                            Cleanup and comments.\n     11
# 24      Added web spider capability for listing ve...     11
# 25      Reworked stage paths to allow %u for usern...     11
# 26           Additional circular reference checking\n     12
# 27                           Documentation skeleton\n     12
# 28        use get instead of setdefault for kwargs.\n     12
# 29                             Better info command.\n     12
# 30                           Color tweaks for find.\n     12
# 31                                spack edit fixed.\n     12
# 32      Spack create works again w/new package for...     12
# 33               Another multimethod test for vdeps\n     12
# 34                      Starting on packaging docs.\n     12
# 35        Bug fix in how class names are determined\n      1
# 36      Local specs now called "anonymous specs"\n...      1
# 37          Add release number to docs and license.\n      1
# 38      Add license to python files and spack scri...      1
# 39            Add line to disable jekyll on github.\n      1
# 40      make empty _static directory "exist" to gi...      1
# 41                          Site configuration docs\n      1
# 42                          Developer documentation\n      1
# 43      Remove trailing whitespace from license te...      1
# 44                      Add README for github repo.\n      1
# 45      Script to make 'spack python' usable acros...      1
# 46                     Add release number to README\n      1
# 47                                  More typo fixes\n      1
# 48                    Fix spelling error in tmp dir\n      1
# 49      Fix bug in staging.\n    \n    - Stage nee...      1
#
#                                    name  utc_offset  year
# 0   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 1   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 2   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 3   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 4   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 5   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 6   b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 7   b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 8   b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 9   b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 10  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 11  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 12  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 13  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 14  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 15  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 16  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 17  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 18  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 19  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 20  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 21  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 22  b'Todd Gamblin <tgamblin@llnl.gov>'       61200  2013
# 23  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 24  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 25  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 26  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 27  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 28  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 29  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 30  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 31  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 32  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 33  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 34  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2013
# 35  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2014
# 36  b'Todd Gamblin <tgamblin@llnl.gov>'        3600  2014
# 37  b'Todd Gamblin <tgamblin@llnl.gov>'        3600  2014
# 38  b'Todd Gamblin <tgamblin@llnl.gov>'        3600  2014
# 39  b'Todd Gamblin <tgamblin@llnl.gov>'        3600  2014
# 40  b'Todd Gamblin <tgamblin@llnl.gov>'        3600  2014
# 41  b'Todd Gamblin <tgamblin@llnl.gov>'        3600  2014
# 42  b'Todd Gamblin <tgamblin@llnl.gov>'        3600  2014
# 43  b'Todd Gamblin <tgamblin@llnl.gov>'        3600  2014
# 44  b'Todd Gamblin <tgamblin@llnl.gov>'        3600  2014
# 45  b'Todd Gamblin <tgamblin@llnl.gov>'        3600  2014
# 46  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2014
# 47  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2014
# 48  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2014
# 49  b'Todd Gamblin <tgamblin@llnl.gov>'       57600  2014

# %%
day_table.columns
# Out:
# Index([   'day_of_week',   'day_of_month',            'doy',  'total_commits',
#           'total_loccs', 'total_messages',          'month',           'year',
#           'total_names',                0],
#       dtype='object')

# %%
for i in range(len(day_table)):
    #pull out values
    a_row = day_table.iloc[i].to_dict()
    dom = a_row[

# %%
len(features_by_day)
# Out:
# 2331

# %%
'''
[[3, 2, 13, 1],
 [4, 2, 14, 0],
 [5, 2, 15, 0],
 [6, 2, 16, 0],
 [7, 2, 17, 0],
 [1, 2, 18, 2],
 [2, 2, 19, 3],
 [3, 2, 20, 2],
 [4, 2, 21, 6],
 [5, 2, 22, 1]]
 '''
features_by_day[:10]  #3=wednesday
# Out:
# [[3, 2, 13, 1],
#  [4, 2, 14, 0],
#  [5, 2, 15, 0],
#  [6, 2, 16, 0],
#  [7, 2, 17, 0],
#  [1, 2, 18, 2],
#  [2, 2, 19, 3],
#  [3, 2, 20, 2],
#  [4, 2, 21, 6],
#  [5, 2, 22, 1]]

# %%
just_commits = [rec[3] for rec in features_by_day]

# %%
max(just_commits)  #49
# Out:
# 49

# %%
n = len(just_commits)
for i in range(max(just_commits)+1):
    print((i, just_commits.count(i)/n))
# Out:
# (0, 0.3341913341913342)
# (1, 0.09523809523809523)
# (2, 0.08065208065208065)
# (3, 0.06992706992706993)
# (4, 0.05405405405405406)
# (5, 0.05148005148005148)
# (6, 0.049335049335049334)
# (7, 0.03517803517803518)
# (8, 0.03088803088803089)
# (9, 0.029601029601029602)
# (10, 0.02702702702702703)
# (11, 0.02145002145002145)
# (12, 0.01673101673101673)
# (13, 0.015873015873015872)
# (14, 0.013728013728013728)
# (15, 0.010725010725010725)
# (16, 0.012012012012012012)
# (17, 0.006864006864006864)
# (18, 0.005577005577005577)
# (19, 0.006435006435006435)
# (20, 0.00429000429000429)
# (21, 0.005148005148005148)
# (22, 0.002574002574002574)
# (23, 0.001716001716001716)
# (24, 0.002145002145002145)
# (25, 0.003432003432003432)
# (26, 0.001716001716001716)
# (27, 0.000429000429000429)
# (28, 0.0)
# (29, 0.002145002145002145)
# (30, 0.001716001716001716)
# (31, 0.001287001287001287)
# (32, 0.000429000429000429)
# (33, 0.0)
# (34, 0.000429000429000429)
# (35, 0.000858000858000858)
# (36, 0.000429000429000429)
# (37, 0.001287001287001287)
# (38, 0.000858000858000858)
# (39, 0.0)
# (40, 0.0)
# (41, 0.000429000429000429)
# (42, 0.0)
# (43, 0.0)
# (44, 0.000429000429000429)
# (45, 0.000429000429000429)
# (46, 0.0)
# (47, 0.000429000429000429)
# (48, 0.0)
# (49, 0.000429000429000429)

# %%
fee_fie_foo()  #break here from Run All to see if want to save
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4124d2a20671> in <module>()
# ----> 1 fee_fie_foo()  #break here from Run All to see if want to save
#
# NameError: name 'fee_fie_foo' is not defined

# %%
import json
with open('features_by_day_'+project+'.txt', 'w') as f:
    f.write(json.dumps(features_by_day))

#Now read the file back into a Python list object
with open('features_by_day_'+project+'.txt', 'r') as f:
    a = json.loads(f.read())
    
len(a) == len(features_by_day)
# Out:
# True

# %%
len(a)
